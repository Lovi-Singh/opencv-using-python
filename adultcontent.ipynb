# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

cap = cv2.VideoCapture('../Downloads/5to6.mp4')
ret,current_frame = cap.read()
previous_frame = current_frame
if cap.isOpened() == False:
    print('ERROR FILE NOT FOUND OR WRONG CODEC USED!')

Number_of_white_pixels = []    
    
while(cap.isOpened()):
    if ret == True:
        current_frame_gray = cv2.cvtColor(current_frame, cv2.COLOR_BGR2GRAY)
        previous_frame_gray = cv2.cvtColor(previous_frame, cv2.COLOR_BGR2GRAY)
    
        frame_diff = cv2.absdiff(current_frame_gray,previous_frame_gray)
        ret_th , thresh_img = cv2.threshold(frame_diff,30,255,cv2.THRESH_BINARY)
        n_white_pix = np.sum(thresh_img == 255)
        Number_of_white_pixels.append(n_white_pix)
        n_white_pix=0
       
        cv2.imshow('frame difference',thresh_img)
        if cv2.waitKey(27) & 0xFF == ord('q'):
            break
            
    else :
        break
    
    previous_frame = current_frame.copy()
    ret , current_frame = cap.read()
               
print('Number of white pixels:', Number_of_white_pixels)        
cap.release()
cv2.destroyAllWindows()
# Out:
# Number of white pixels: [0, 41468, 35, 20009, 0, 0, 29212, 0, 40015, 0, 44400, 0, 54392, 0, 0, 63528, 0, 0, 60921, 0, 0, 41739, 0, 34665, 0, 20231, 0, 0, 21907, 0, 31508, 0, 0, 39224, 0, 37925, 0, 37382, 58891, 11, 2, 62408, 53499, 33135, 1, 31175, 49976, 70412, 67906, 55600, 44000, 11, 40084, 40183, 33658, 24443, 14515, 31966, 57656, 9, 62351, 61358, 66294, 61843, 56866, 52004, 7, 34834, 16165, 30359, 51704, 57069, 51182, 0, 44920, 44560, 37986, 27796, 27301, 29953, 34659, 11, 42145, 59660, 73365, 79123, 75484, 63092, 0, 43846, 54619, 50352, 0, 0, 60114, 84276, 84780, 0, 60875, 37351, 26281, 16799, 25276, 55032, 8, 81403, 0, 86201, 83042, 81820, 79764, 68913, 38, 64352, 54155, 57242, 66357, 53678, 36569, 32024, 22, 51771, 63870, 59263, 53571, 58422, 57001, 0, 55479, 60985, 50597, 0, 29915, 0, 0, 47650, 0, 64594, 0, 0, 66024, 0, 72627, 0, 70338, 0, 0, 41727, 0, 19601, 3, 9501, 0, 27962, 0, 44179, 0, 50872, 0, 0, 43579, 0, 64944, 0, 74949, 0, 65174, 0, 0, 40101, 0, 0, 24549, 0, 48009, 0, 60582, 0, 75994, 65070, 49, 57043, 37051, 18116, 21646, 40949, 55476, 21, 72482, 84449, 73344, 49599, 28157, 45374, 60372, 0, 0, 69634, 0, 73801, 0, 0, 73314, 0, 65778, 0, 45110, 0, 13243, 0, 23210, 6, 0, 52139, 0, 70863, 0, 79958, 75382, 49308, 0, 10712, 36562, 65610, 74902, 69201, 51643, 1, 31992, 0, 14389, 17947, 30345, 54444, 73802, 1, 86008, 0, 0, 79940, 0, 58107, 0, 0, 27122, 0, 51352, 0, 84380, 0, 0, 90299, 0, 79398, 0, 0, 57353, 0, 37097, 0, 